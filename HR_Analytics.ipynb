# %% [markdown]
# <a href="https://colab.research.google.com/github/JeswinThomasAJ/Business-Analytics-with-Python/blob/main/HR_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/HRDataset_v14.csv")
print(df)
# Out:
#                 Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0         Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 1    Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2           Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3                Alagbe,Trina  10088.0        1.0              1.0  Female
# 4            Anderson, Carol   10069.0        0.0              2.0    Male
# ..                        ...      ...        ...              ...     ...
# 307        Ybarra, Catherine   10301.0        0.0              0.0  Female
# 308          Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309               Zhou, Julia  10043.0        0.0              0.0    Male
# 310             Zima, Colleen  10271.0        0.0              4.0    Male
# 311                       NaN      NaN        NaN              NaN    Male
#
# ...

# %%
pd.read_csv("/content/HRDataset_v14.csv")
# Out:
#                 Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0         Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 1    Ait Sidi, Karthikeyan     10084.0        1.0              1.0    Male
# 2           Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3                Alagbe,Trina  10088.0        1.0              1.0  Female
# 4            Anderson, Carol   10069.0        0.0              2.0    Male
# ..                        ...      ...        ...              ...     ...
# 307        Ybarra, Catherine   10301.0        0.0              0.0  Female
# 308          Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309               Zhou, Julia  10043.0        0.0              0.0    Male
# 310             Zima, Colleen  10271.0        0.0              4.0    Male
# 311                       NaN      NaN        NaN              NaN    Male
#
# ...

# %%
df.loc[df["Position"]=="Production Technician I"].count()
# Out:
# Employee_Name                 137
# EmpID                         137
# MarriedID                     137
# MaritalStatusID               137
# Gender                        137
# EmpStatusID                   137
# DeptID                        137
# PerfScoreID                   137
# FromDiversityJobFairID        137
# Salary                        137
# Termd                         137
# PositionID                    137
# Position                      137
# State                         137
# Zip                           137
# DOB                           137
# Sex                           137
# MaritalDesc                   137
# CitizenDesc                   137
# DateofHire                    137
# DateofTermination              52
# TermReason                    137
# EmploymentStatus              137
# Department                    137
# ManagerName                   137
# ManagerID                     133
# RecruitmentSource             137
# ...

# %%
df.loc[df["Gender"]=="Male"].count()
# Out:
# Employee_Name                 193
# EmpID                         193
# MarriedID                     193
# MaritalStatusID               193
# Gender                        194
# EmpStatusID                   193
# DeptID                        193
# PerfScoreID                   193
# FromDiversityJobFairID        193
# Salary                        193
# Termd                         193
# PositionID                    193
# Position                      193
# State                         193
# Zip                           193
# DOB                           193
# Sex                           193
# MaritalDesc                   193
# CitizenDesc                   193
# DateofHire                    193
# DateofTermination              64
# TermReason                    193
# EmploymentStatus              193
# Department                    193
# ManagerName                   193
# ManagerID                     187
# RecruitmentSource             193
# ...

# %%
df.loc[df["ManagerName"]=="Michael Albert"].count()
# Out:
# Employee_Name                 22
# EmpID                         22
# MarriedID                     22
# MaritalStatusID               22
# Gender                        22
# EmpStatusID                   22
# DeptID                        22
# PerfScoreID                   22
# FromDiversityJobFairID        22
# Salary                        22
# Termd                         22
# PositionID                    22
# Position                      22
# State                         22
# Zip                           22
# DOB                           22
# Sex                           22
# MaritalDesc                   22
# CitizenDesc                   22
# DateofHire                    22
# DateofTermination              9
# TermReason                    22
# EmploymentStatus              22
# Department                    22
# ManagerName                   22
# ManagerID                     22
# RecruitmentSource             22
# PerformanceScore              22
# ...

# %%
df.loc[df["EmploymentStatus"]=="Active"]
# Out:
#            Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0    Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 3           Alagbe,Trina  10088.0        1.0              1.0  Female
# 5      Anderson, Linda    10002.0        0.0              0.0    Male
# 6        Andreola, Colby  10194.0        0.0              0.0  Female
# 7            Athwal, Sam  10062.0        0.0              4.0    Male
# ..                   ...      ...        ...              ...     ...
# 305        Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306       Woodson, Jason  10135.0        0.0              0.0    Male
# 308     Zamora, Jennifer  10010.0        0.0              0.0    Male
# 309          Zhou, Julia  10043.0        0.0              0.0    Male
# 310        Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[(df["EmploymentStatus"]=="Active") & (df["MaritalDesc"]=="Married")]
# Out:
#          Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 3         Alagbe,Trina  10088.0        1.0              1.0  Female
# 16    Beak, Kimberly    10023.0        1.0              1.0    Male
# 22       Billis, Helen  10003.0        1.0              1.0  Female
# 26   Boutwell, Bonalyn  10081.0        1.0              1.0  Female
# 29          Brown, Mia  10238.0        1.0              1.0  Female
# ..                 ...      ...        ...              ...     ...
# 271   Sullivan, Kissy   10158.0        1.0              1.0    Male
# 272  Sullivan, Timothy  10117.0        1.0              1.0    Male
# 275       Tannen, Biff  10173.0        1.0              1.0  Female
# 287      Turpin, Jumil  10045.0        1.0              1.0    Male
# 288    Valentin,Jackie  10205.0        1.0              1.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# ...

# %%
df.loc[(df["EmploymentStatus"]=="Active") & (df["Salary"]<=60000)]
# Out:
#             Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 5       Anderson, Linda    10002.0        0.0              0.0    Male
# 7             Athwal, Sam  10062.0        0.0              4.0    Male
# 8        Bachiochi, Linda  10114.0        0.0              0.0    Male
# 9      Bacong, Alejandro   10250.0        0.0              2.0    Male
# 13   Barone, Francesco  A  10265.0        0.0              0.0    Male
# ..                    ...      ...        ...              ...     ...
# 278      Terry, Sharlene   10161.0        0.0              0.0  Female
# 281     Tippett, Jeanette  10123.0        0.0              2.0    Male
# 288       Valentin,Jackie  10205.0        1.0              1.0    Male
# 291      Villanueva, Noah  10253.0        0.0              0.0    Male
# 310         Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# ...

# %%
df.loc[(df["Position"]=="Production Technician II") & (df["EngagementSurvey"]==df["EngagementSurvey"].max())]
# Out:
#           Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 123    Hankard, Earnest  10074.0        0.0              0.0    Male
# 127  Hendrickson, Trina  10075.0        0.0              0.0    Male
# 177   Manchester, Robyn  10077.0        1.0              1.0    Male
# 178      Mancuso, Karen  10073.0        1.0              1.0  Female
# 182     Carthy, B'rigit  10076.0        0.0              0.0  Female
# 206     Oliver, Brooke   10078.0        1.0              1.0    Male
# 304  Winthrop, Jordan    10033.0        0.0              0.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# 123          1.0     5.0          3.0                     0.0  64246.0  ...
# 127          5.0     5.0          3.0                     0.0  68099.0  ...
# 177          2.0     5.0          3.0                     0.0  62385.0  ...
# 178          5.0     5.0          3.0                     0.0  68407.0  ...
# ...

# %%
df.loc[(df["Position"]=="Production Technician II") & (df["EngagementSurvey"]==5)]
# Out:
#           Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 123    Hankard, Earnest  10074.0        0.0              0.0    Male
# 127  Hendrickson, Trina  10075.0        0.0              0.0    Male
# 177   Manchester, Robyn  10077.0        1.0              1.0    Male
# 178      Mancuso, Karen  10073.0        1.0              1.0  Female
# 182     Carthy, B'rigit  10076.0        0.0              0.0  Female
# 206     Oliver, Brooke   10078.0        1.0              1.0    Male
# 304  Winthrop, Jordan    10033.0        0.0              0.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# 123          1.0     5.0          3.0                     0.0  64246.0  ...
# 127          5.0     5.0          3.0                     0.0  68099.0  ...
# 177          2.0     5.0          3.0                     0.0  62385.0  ...
# 178          5.0     5.0          3.0                     0.0  68407.0  ...
# ...

# %%
df.loc[(df["Salary"]==df["Salary"].max()) & df["Position"]]
# Out:
#     Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  EmpStatusID  \
# 150   King, Janet  10089.0        1.0              1.0  Female          1.0
#
#      DeptID  PerfScoreID  FromDiversityJobFairID    Salary  ...  \
# 150     2.0          3.0                     0.0  250000.0  ...
#
#      PerformanceRating  StandardHours StockOptionLevel TotalWorkingYears  \
# 150                  3             80                1                20
#
#      TrainingTimesLastYear WorkLifeBalance YearsAtCompany YearsInCurrentRole  \
# 150                      2               3             20                  7
#
#     YearsSinceLastPromotion YearsWithCurrManager
# 150                       2                   13
#
# [1 rows x 56 columns]
# ...

# %%
sal=df["Salary"].mean()
print(sal)
df.loc[df["Salary"]<sal]
# Out:
# 69020.6848874598
#              Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 0      Adinolfi, Wilson  K  10026.0        0.0              0.0  Female
# 2        Akinkuolie, Sarah  10196.0        1.0              1.0    Male
# 3             Alagbe,Trina  10088.0        1.0              1.0  Female
# 4         Anderson, Carol   10069.0        0.0              2.0    Male
# 5        Anderson, Linda    10002.0        0.0              0.0    Male
# ..                     ...      ...        ...              ...     ...
# 303  Williams, Jacquelyn    10264.0        0.0              0.0    Male
# 305          Wolk, Hang  T  10174.0        0.0              0.0  Female
# 306         Woodson, Jason  10135.0        0.0              0.0    Male
# 307     Ybarra, Catherine   10301.0        0.0              0.0  Female
# 310          Zima, Colleen  10271.0        0.0              4.0    Male
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# ...

# %%
df.loc[(df["Salary"]<sal) & (df["EmpSatisfaction"]==df["EmpSatisfaction"].min())]
# Out:
#         Employee_Name    EmpID  MarriedID  MaritalStatusID  Gender  \
# 72  Dietrich, Jenna    10304.0        0.0              0.0    Male
# 83     Erilus, Angela  10299.0        0.0              3.0  Female
#
#     EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID   Salary  ...  \
# 72          1.0     6.0          1.0                     0.0  59231.0  ...
# 83          1.0     5.0          1.0                     0.0  56847.0  ...
#
#     PerformanceRating  StandardHours StockOptionLevel TotalWorkingYears  \
# 72                  3             80                0                 1
# 83                  3             80                3                17
#
#     TrainingTimesLastYear WorkLifeBalance YearsAtCompany YearsInCurrentRole  \
# 72                      4               3              1                  1
# 83                      3               3             13                 11
#
#    YearsSinceLastPromotion YearsWithCurrManager
# ...

# %%
import matplotlib.pyplot as plt

x=df["DistanceFromHome"]
y=df["EmpSatisfaction"]
plt.bar(x,y,width=.5)
# Out:
# <BarContainer object of 312 artists>

# %%
df.loc[df["StockOptionLevel"]>0].Employee_Name
# Out:
# 1      Ait Sidi, Karthikeyan
# 4              Anderson, Carol
# 6               Andreola, Colby
# 7                   Athwal, Sam
# 9            Bacong, Alejandro
#                  ...
# 306              Woodson, Jason
# 307          Ybarra, Catherine
# 308            Zamora, Jennifer
# 309                 Zhou, Julia
# 311                         NaN
# Name: Employee_Name, Length: 172, dtype: object

# %%
df.loc[df["PerformanceRating"]>3].Employee_Name.count()
# Out:
# 57

# %%
df.loc[df["EmpStatusID"]==5].count()
# Out:
# Employee_Name                 88
# EmpID                         88
# MarriedID                     88
# MaritalStatusID               88
# Gender                        88
# EmpStatusID                   88
# DeptID                        88
# PerfScoreID                   88
# FromDiversityJobFairID        88
# Salary                        88
# Termd                         88
# PositionID                    88
# Position                      88
# State                         88
# Zip                           88
# DOB                           88
# Sex                           88
# MaritalDesc                   88
# CitizenDesc                   88
# DateofHire                    88
# DateofTermination             88
# TermReason                    88
# EmploymentStatus              88
# Department                    88
# ManagerName                   88
# ManagerID                     88
# RecruitmentSource             88
# PerformanceScore              88
# ...

# %%
df.loc[df["Department"]=="IT/IS"].Employee_Name.count()
# Out:
# 50

# %%
a1=df.loc[df["Department"]=="Admin Offices"].EmpID.count()
a2=df.loc[df["Department"]=="IT/IS"].EmpID.count()
a3=df.loc[df["Department"]=="Executive Officer"].EmpID.count()
a4=df.loc[df["Department"]=="Production"].EmpID.count()
a5=df.loc[df["Department"]=="Sales"].EmpID.count()
a6=df.loc[df["Department"]=="Software Engineering"].EmpID.count()
print(a1)
print(a2)
print(a3)
print(a4)
print(a5)
print(a6)
# Out:
# 9
# 50
# 0
# 0
# 31
# 11
